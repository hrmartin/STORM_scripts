# %%
import importlib
import nearest_neighbor
import numpy as np
import matplotlib.pyplot as plt
importlib.reload(nearest_neighbor)
d = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1'
#d = '/home/masse/Storm-Microscopy-Analysis/Data/'
NN = nearest_neighbor.NN(d)

# %%
""" 
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 25
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 100
self.dbscan_max_diameter = 1000
"""

importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)

labels = ['WASP', 'Actin', 'TUB', 'CNP', 'MBP']
for i in range(len(labels)):
    NN.run_analysis(marker = labels[i])
    
NN.plot_results_from_files()
# Out:
# OL1-BIN1-CNP
# ['C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\BIN1-Run1.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\BIN1-Run2.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\BIN1-Run3.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\BIN1-Run4.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\CNP-Run1.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\CNP-Run2.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\CNP-Run3.csv', 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL1\\OL1-BIN1-CNP\\CNP-Run4.csv']
# OL1-BIN1-MBP
# ...

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 25
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 100
self.dbscan_max_diameter = 1000
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)

NN.__init__(data_dir = d)

labels = ['WASP', 'Actin', 'TUB', 'CNP', 'MBP']
    
for 
NN.load_and_cluster_data()
NN.plot_results_from_files()

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 25
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 100
self.dbscan_max_diameter = 1000
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)

NN.__init__(data_dir = d)

labels = ['WASP', 'Actin', 'TUB', 'CNP', 'MBP']
    
NN.plot_results_from_files()
# Out:
# t-test p =  nan
# ranksum p =  nan
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\stats.py:4971: RuntimeWarning: invalid value encountered in double_scalars
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 25
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 50
self.dbscan_max_diameter = 1000
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)
NN.plot_main_results(['GluA1','PSD','Syn','Bassoon'])
# Out:
# Working directories... []
# []
# t-test p =  nan
# ranksum p =  nan
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\stats.py:4971: RuntimeWarning: invalid value encountered in double_scalars
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 25
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 25
self.dbscan_max_diameter = 500
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)
NN.plot_main_results(['GluA1','PSD','Syn','Bassoon'])
# Out:
# Working directories... []
# []
# t-test p =  nan
# ranksum p =  nan
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\stats.py:4971: RuntimeWarning: invalid value encountered in double_scalars
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 50
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 25
self.dbscan_max_diameter = 1000
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)
NN.plot_main_results(['GluA1','PSD','Syn','Bassoon'])
# Out:
# Working directories... []
# []
# t-test p =  nan
# ranksum p =  nan
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\stats.py:4971: RuntimeWarning: invalid value encountered in double_scalars
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 50
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 25
self.dbscan_max_diameter = 1000
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)
NN.plot_main_results(['GluA1','PSD','Syn','Bassoon'])
# Out:
# Working directories... []
# []
# t-test p =  nan
# ranksum p =  nan
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\stats.py:4971: RuntimeWarning: invalid value encountered in double_scalars
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...

# %%
"""        
self.dbscan_max_dist = 50
self.dbscan_min_samples = 3
self.dbscan_min_samples_per_cluster = 50
self.dbscan_max_samples_per_cluster = 10000
self.dbscan_min_diameter = 25
self.dbscan_max_diameter = 1000
"""

importlib.reload(cluster)
importlib.reload(nearest_neighbor)
NN = nearest_neighbor.NN(d)
NN.plot_main_results(['GluA1','PSD','Syn','Bassoon'])
# Out:
# Working directories... []
# []
# t-test p =  nan
# ranksum p =  nan
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\hanna\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\stats.py:4971: RuntimeWarning: invalid value encountered in double_scalars
#   z = (s - expected) / np.sqrt(n1*n2*(n1+n2+1)/12.0)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\hanna\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams["font.family"] = "Arial"
#print(plt.rcParams)
import matplotlib.pyplot as plt
print(intearact_prob)
c = 0.1
f = plt.figure(figsize=(6,4))
ax = f.add_subplot(1,1,1)
for i in range(len(intearact_prob)):
    u = np.linspace(i+1-c, i+1+c, len(intearact_prob[i]))
    plt.plot(u, intearact_prob[i],'k.',markersize=8)
    plt.plot([i+1-0.45, i+1+0.45],[np.median(intearact_prob[i]),np.median(intearact_prob[i])],'k')
ax.set_xticks([1,2,3,4,5,6,7])   
ax.set_xticklabels(['Syn','Amph1','Syp','CaMKII','PSD95','GluA1','Bassoon']) 
ax.set_ylabel('Proportion')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('min_cluster50_interact_pts_10_dist_20.tif', format='tif')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4968b5efefdf> in <module>()
#       5 #print(plt.rcParams)
#       6 import matplotlib.pyplot as plt
# ----> 7 print(intearact_prob)
#       8 c = 0.1
#       9 f = plt.figure(figsize=(6,4))
#
# NameError: name 'intearact_prob' is not defined

# %%
importlib.reload(cluster)
importlib.reload(nearest_neighbor)
d = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL3-MBP488-Bin1555-CN647'
NN = nearest_neighbor.NN(d)
NN_dist, subdirs = NN.search_dirs()

# %%
b = np.arange(0,200,2)
for i in range(7):
    print(subdirs[i])
    h = np.histogram(NN_dist[i], b)[0]
    h = h/np.sum(h)
    plt.hold(False)
    plt.plot(b[:-1],h)
    plt.show()

# %%
NN_dist, subdirs = NN.search_dirs()

# %%
b = np.arange(0,200,2)
col = ['b','r','g','k','c','m','y']
y = []
for i in range(7):
    print(subdirs[i])
    n = np.array(NN_dist[i])
    h0 = np.histogram(n[:,0], b)[0]
    h0 = h0/np.sum(h0)
    h1 = np.histogram(n[:,1], b)[0]
    h1 = h1/np.sum(h1)
    plt.hold(False)
    plt.plot(b[:-1],h0,'b')
    #plt.hold(True)
    plt.plot(b[:-1],h1,color=col[i])
    #plt.plot(b[:-1],h1-h0,'r')
    y.append(h0/h1)
for i in range(7):
    plt.plot(b[:20],y[i][:20],color=col[i])
    plt.hold(True)
plt.show()

# %%
n = np.array(NN_dist[0])
print(n.shape)

# %%
importlib.reload(cluster)
f = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL3-BIN1555-CNP647/BIN1-Run1.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-GluA1/GluA1-Run3.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-PSD95/PSD95_Run3.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-Amph1/Amph1_Field4.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1_CaMKII/CaMKII-Run2.csv'
c = cluster.Cluster(f)
f1 = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL3-BIN1555-CNP647/BIN1-Run1.csv'
#f1 = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-GluA1/BIN1-Run3.csv'
#f1 = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-PSD95/BIN1_Run3.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-Amph1/BIN1_Field4.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1_CaMKII/BIN1-Run2.csv'
c1 = cluster.Cluster(f1)
labels = c.db_scan()
x = c.return_coords()
labels1 = c1.db_scan()
x1 = c1.return_coords()
x1 = c1.return_coords()
d = 2500
plt.figure(figsize=(8,4))
#plt.plot(x[:,0],x[:,1],'.', color = 'b')
for i in range(9999):
    
    # Synaptic Marker - GREEN
    ind = np.where((labels==i)*(x[:,2]>-d)*(x[:,2]<d))[0]
    if len(ind)> 5:
        cl = np.random.rand(4)
        cl = [0,1,0,1]
        #cl[0] = 0
        #cl[3] = 1
        #cl[1:3] = (np.mean(x[ind,2])+250)/500
        #cl[1:3] /= 3
        plt.plot(x[ind,0],x[ind,1],'.', color = cl)
    
    # BIN1 Marker - MAGENTA
    ind = np.where((labels1==i)*(x1[:,2]>-d)*(x1[:,2]<d))[0]
    if len(ind)> 0:
        cl = np.random.rand(4)
        cl = [1,0,1,1]
        #cl[2] = 1
        #cl[:2] = (np.mean(x1[ind,2])+250)/500
        #cl[:2] /= 3
        #cl[3] = 1
        plt.plot(x1[ind,0],x1[ind,1],'.', color = cl)
   

#plt.xlim([3500,4000])
#plt.ylim([8700,9200])
plt.xlim([1000,6000])
plt.ylim([7500,10000])
plt.savefig('db_scan_example', format = 'pdf')
plt.show()

# %%
importlib.reload(cluster)
f = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL3-BIN1555-CNP647/BIN1-Run1.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-GluA1/GluA1-Run3.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-PSD95/PSD95_Run3.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-Amph1/Amph1_Field4.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1_CaMKII/CaMKII-Run2.csv'
c = cluster.Cluster(f)
f1 = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV/OL3-BIN1555-CNP647/CNP-Run1.csv'
#f1 = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-GluA1/BIN1-Run3.csv'
#f1 = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-PSD95/BIN1_Run3.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1-Amph1/BIN1_Field4.csv'
#f = '/home/masse/Storm-Pierre/SuperResolutionMicroscopy_STORM_Pierre/STORM/CSV/BIN1_CaMKII/BIN1-Run2.csv'
c1 = cluster.Cluster(f1)
labels = c.db_scan()
x = c.return_coords()
labels1 = c1.db_scan()
x1 = c1.return_coords()
d = 5000
plt.figure(figsize=(15,15))
#plt.plot(x[:,0],x[:,1],'.', color = 'b')
for i in range(9999):
    
    # Synaptic Marker - RED
    ind = np.where((labels==i)*(x[:,2]>-d)*(x[:,2]<d))[0]
    if len(ind)> 5:
        cl = np.random.rand(4)
        cl[0] = 1
        cl[3] = 1
        #cl[1:3] = (np.mean(x[ind,2])+250)/500
        cl[1:3] = 0
        plt.plot(x[ind,0],x[ind,1],'.', color = cl)
    
    # BIN1 Marker - Blue
    ind = np.where((labels1==i)*(x1[:,2]>-d)*(x1[:,2]<d))[0]
    if len(ind)> 0:
        cl = np.random.rand(4)
        cl[2] = 1
        #cl[:2] = (np.mean(x1[ind,2])+250)/500
        cl[:2] = 0
        cl[3] = 1
        plt.plot(x1[ind,0],x1[ind,1],'.', color = cl)
   

#plt.xlim([3500,4000])
#plt.ylim([8700,9200])
plt.xlim([10000,15000])
plt.ylim([2000,7000])
plt.savefig('BIN1-CaMKII-Run2.tif', format = 'tif')
plt.show()

# %%
print(np.min(x[:,2]))
print(np.max(x[:,2]))

# %%
print(y.shape)
print(p_y.shape)
p_y_x = np.stack(p_y_x_collection)
print(p_y_x.shape)
plt.figure(figsize=(15,15))
plt.plot(x[:,0], x[:,1],'b.')
ind = np.where(p_y>1e-7)[0]
#plt.plot(y[ind,0], y[ind,1],'c.')
ind = np.where(p_y>1e-6)[0]
#plt.plot(y[ind,0], y[ind,1],'m.')
ind = np.where(p_y>1e-5)[0]
plt.plot(y[ind,0], y[ind,1],'r.')
plt.xlim([500,4000])
plt.ylim([1500,5000])
plt.show()

# %%
plt.plot(np.mean(distances,axis=0))
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nbrs = NearestNeighbors(n_neighbors=250, algorithm='kd_tree').fit(x)

# %%
dist, ind = nbrs.kneighbors(x)

# %%
print(dist.shape)

# %%
plt.plot(dist[0,:])
plt.plot(dist[1,:],'r')
plt.plot(dist[2,:],'g')
plt.plot(dist[3,:],'k')
plt.plot(dist[4,:],'c')
plt.plot(dist[5,:],'y')
plt.show()

# %%
s=np.diff(dist,n=1,axis=1)

# %%
plt.imshow(s[:10,:100],aspect='auto', interpolation='none', clim = (0,20))
plt.colorbar()
plt.show()

# %%
u =  np.arange(0,130000,1)
plt.figure(figsize=(20,10))
plt.plot(x[u,0],x[u,1],'b.')
plt.axes().set_aspect('equal', 'datalim')
plt.xlim([5000,10000])
plt.ylim([5000,10000])
plt.show()

# %%
ind = np.where(dist[:,2]<50)[0]
print(len(ind))
plt.figure(figsize=(20,10))
plt.plot(x[:,0],x[:,1],'b.')
plt.plot(x[ind,0],x[ind,1],'r.')
plt.axes().set_aspect('equal', 'datalim')
#plt.xlim([6000,7000])
#plt.ylim([7000,8000])
plt.show()

# %%
import nearest_neighbor
import importlib
importlib.reload(nearest_neighbor)

# %%
d = 'C:/Users/hanna/Documents/Thinakaran/Data/GSD CSV'
NN = nearest_neighbor.NN(d)

# %%
NN_dist, subdirs = NN.search_dirs()

# %%
print(np.log(np.exp(20)/(np.exp(80)+np.exp(20)+np.exp(20))))

# %%
print(np.exp(300))

# %%
z = np.random.uniform(-1.,1., size=(100000,100))
print(z.shape)
w0 = np.random.uniform(-1.,1., size=(100,1))
w1 = np.random.uniform(-1.,1., size=(100,1))
z0 = np.dot(z,w0)
z1 = np.dot(z,w1)
import scipy.stats as ss

# %%
plt.plot(z0,z1,'k.')
plt.show()
r = ss.pearsonr(z0,z1)
print(r)

# %%
s='test'
x = ['te','re'] in s
print(x)

# %%
s=np.array([0,1,2,3,4,5])
s1=s[s>1]
print(s,s1)
